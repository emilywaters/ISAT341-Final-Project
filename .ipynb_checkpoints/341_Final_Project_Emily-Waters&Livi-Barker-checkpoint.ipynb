# %% [markdown]
# <center>
#     <h2 style="color:blue;">ISAT 341: Machine Learning and Data Science
# </h2>
# <h3 style="color:green;">Final Project: Image Classification with Scikit-Learn
# </h3>
#
# </center>
#     <h5 style="color:orange;">Emily Waters and Livi Barker
#     </h5>
# </center>
